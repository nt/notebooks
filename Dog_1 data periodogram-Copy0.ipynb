# %%
import os, sys
import scipy.io
import numpy as np

# %%
interictal = scipy.io.loadmat('/data/datasets/Dog_1/Dog_1_interictal_segment_0014.mat')
seg_name =  [k for k in interictal.keys() if k not in ["__version__", '__header__', '__globals__']][0]
data, data_length_sec, sampling_frequency, channels, sequence = interictal[seg_name][0][0]

# %%
print data.shape
print sampling_frequency
# Out:
# (16, 239766)
# [[ 399.6097561]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=16, ncols=1, figsize=(25, 13))
fig.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in fig.axes[:-1]], visible=False)

for i in range(0, 16):
    axes[i].plot(data[i][0:3000])
    axes[i].set_title(channels[0][i][0])

# %%
from scipy import signal

# %%
print type(data[0][:])
# Out:
# <type 'numpy.ndarray'>

# %%
f, Pxx_den = signal.welch (data[2][:], sampling_frequency[0][0], nperseg=128)

# %%
plt.semilogy(f, Pxx_den)
plt.ylim([1e-7, 1e2])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
