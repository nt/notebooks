# %%
import os, sys
import scipy.io
import numpy as np

# %%
interictal = scipy.io.loadmat('/data/datasets/Dog_1/Dog_1_interictal_segment_0014.mat')
seg_name =  [k for k in interictal.keys() if k not in ["__version__", '__header__', '__globals__']][0]
data, data_length_sec, sampling_frequency, channels, sequence = interictal[seg_name][0][0]

# %%
print data.shape
data[4][:] = 0
# Out:
# (16, 239766)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot(data, labels):
    rows = data.shape[0]
    fig, axes = plt.subplots(nrows=rows, ncols=1, figsize=(25, rows))
    fig.subplots_adjust(hspace=0)
    plt.setp([a.get_xticklabels() for a in fig.axes[:-1]], visible=False)

    for i in range(0, rows):
        axes[i].plot(data[i][:])
        axes[i].set_title(labels[i])

plot(data, [c[0] for c in channels[0]])

# %%
from sklearn.decomposition import fastica

out = fastica(data.T, n_components = 6)
# Out:
# /data/.virtualenvs/env/local/lib/python2.7/site-packages/sklearn/decomposition/fastica_.py:282: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   X -= X_mean[:, np.newaxis]

# %%
K, W, S = out

# %%
print S.shape
# Out:
# (239766, 6)

# %%
plot(S.T, [c[0] for c in channels[0]])

# %%
with_pol_order_2 = np.concatenate((data, (data ** 2)))

# %%
K2, W2, S2 = fastica(data.T, n_components = 6)
# Out:
# /data/.virtualenvs/env/local/lib/python2.7/site-packages/sklearn/decomposition/fastica_.py:282: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   X -= X_mean[:, np.newaxis]

# %%
plot(S2.T, [c[0] for c in channels[0]])

# %%
with_pol_order_3 = np.concatenate((data, (data ** 2), (data ** 3)))

# %%
K3, W3, S3 = fastica(data.T, n_components = 6)
# Out:
# /data/.virtualenvs/env/local/lib/python2.7/site-packages/sklearn/decomposition/fastica_.py:282: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   X -= X_mean[:, np.newaxis]

# %%
plot(S3.T, [c[0] for c in channels[0]])
